# %%
# import libraries
import numpy as np
import pandas as pd

# %%
#load dataset
df = pd.read_csv("Downloads\india-state-wise-analysis")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6dc3b65f694d> in <cell line: 1>()
# ----> 1 df = pd.read_csv("Downloads\india-state-wise-analysis")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
url = 'https://github.com/xscientisttech/detaset/blob/main/india-state-wise-data-analysis.csv'
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-5451159775a5> in <cell line: 2>()
#       1 url = 'https://github.com/xscientisttech/detaset/blob/main/india-state-wise-data-analysis.csv'
# ----> 2 df = pd.read_csv(url)
#
# ...

# %%
#load dataset
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-14a94d18-cfc7-4c78-895f-27a819154ac4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14a94d18-cfc7-4c78-895f-27a819154ac4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['india-state-wise-data-analysis.csv']))
print(df)
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
df.head()
# Out:
#                                     State & District  Population    Male  \
# 0  district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1  district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2  district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3  district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4  district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
#
#    Female  Literate  Male_Literate  Female_Literate    SC  Male_SC  Female_SC  \
# 0  396164    439654         282823           156831  1048     1046          2
# 1  355704    335649         207741           127908   368      343         25
# 2   54516     93770          62834            30936   488      444         44
# 3   63017     86236          56301            29935    18       12          6
# 4  224936    261724         163333            98391   556      406        150
#
# ...

# %%
#split one column into 3 distinct columns
df[['district_Code','state_Name','district_Name']] = df['State & District'].str.split(',',expand=True)

# %%
df
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
df=df.drop(['district_code'] ,axis=1)

# %%
df
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
df[['district_code','state_name','district_name']] = df['State & District'].str.split(',',expand=True)

# %%
df
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
#remove the 'district_code:' prefix from each value in the 'district_code' column.
df['district_code'] = df['district_code'].str.replace('district_code:', '')

# %%
df
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
#remove the 'state_name:' prefix from each value in the 'state_name' column.
df['state_name'] = df['state_name'].str.replace('state_name:', '')

# %%
df
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
#remove the 'district_name:' prefix from each value in the 'district_name' column.
df['district_name'] = df['district_name'].str.replace('district_name:', '')

# %%
df
# Out:
#                                       State & District  Population    Male  \
# 0    district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190
# 1    district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2    district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3    district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4    district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
# ..                                                 ...         ...     ...
# 635  district_code:636, state_name:PONDICHERRY, dis...       41816   19143
# 636  district_code:637, state_name:PONDICHERRY, dis...      200222   97809
# 637  district_code:638, state_name:ANDAMAN AND NICO...       36842   20727
# 638  district_code:639, state_name:ANDAMAN AND NICO...      105597   54861
# 639  district_code:640, state_name:ANDAMAN AND NICO...      238142  127283
#
# ...

# %%
df=df.drop('State & District',axis=1)

# %%
df
# Out:
#      Population    Male  Female  Literate  Male_Literate  Female_Literate  \
# 0        870354  474190  396164    439654         282823           156831
# 1        753745  398041  355704    335649         207741           127908
# 2        133487   78971   54516     93770          62834            30936
# 3        140802   77785   63017     86236          56301            29935
# 4        476835  251899  224936    261724         163333            98391
# ..          ...     ...     ...       ...            ...              ...
# 635       41816   19143   22673     36470          16610            19860
# 636      200222   97809  102413    154916          79903            75013
# 637       36842   20727   16115     25332          15397             9935
# 638      105597   54861   50736     78683          43186            35497
# 639      238142  127283  110859    190266         105794            84472
#
#         SC  Male_SC  Female_SC      ST  ...  Other_Education  \
# ...

# %%
#transfer the last three columns to the first three columns:
# Get column names
columns = df.columns.tolist()

# Rearrange columns
new_order = columns[-3:] + columns[:-3]
df = df[new_order]

# %%
df
# Out:
#     district_code                    state_name               district_name  \
# 0               1             JAMMU AND KASHMIR                     Kupwara
# 1               2             JAMMU AND KASHMIR                      Badgam
# 2               3             JAMMU AND KASHMIR                 Leh(Ladakh)
# 3               4             JAMMU AND KASHMIR                      Kargil
# 4               5             JAMMU AND KASHMIR                       Punch
# ..            ...                           ...                         ...
# 635           636                   PONDICHERRY                        Mahe
# 636           637                   PONDICHERRY                    Karaikal
# 637           638   ANDAMAN AND NICOBAR ISLANDS                    Nicobars
# 638           639   ANDAMAN AND NICOBAR ISLANDS   North  AND Middle Andaman
# 639           640   ANDAMAN AND NICOBAR ISLANDS               South Andaman
#
# ...

# %%
#check for null values
df=df.isnull()

# %%
df
# Out:
#      district_code  state_name  district_name  Population   Male  Female  \
# 0            False       False          False       False  False   False
# 1            False       False          False       False  False   False
# 2            False       False          False       False  False   False
# 3            False       False          False       False  False   False
# 4            False       False          False       False  False   False
# ..             ...         ...            ...         ...    ...     ...
# 635          False       False          False       False  False   False
# 636          False       False          False       False  False   False
# 637          False       False          False       False  False   False
# 638          False       False          False       False  False   False
# 639          False       False          False       False  False   False
#
#      Literate  Male_Literate  Female_Literate     SC  ...  \
# ...

# %%
print(df)
# Out:
#      district_code  state_name  district_name  Population   Male  Female  \
# 0            False       False          False       False  False   False
# 1            False       False          False       False  False   False
# 2            False       False          False       False  False   False
# 3            False       False          False       False  False   False
# 4            False       False          False       False  False   False
# ..             ...         ...            ...         ...    ...     ...
# 635          False       False          False       False  False   False
# 636          False       False          False       False  False   False
# 637          False       False          False       False  False   False
# 638          False       False          False       False  False   False
# 639          False       False          False       False  False   False
#
#      Literate  Male_Literate  Female_Literate     SC  ...  \
# ...

# %%
#check for non null values and data type of each column
df=df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   district_code                     640 non-null    bool
#  1   state_name                        640 non-null    bool
#  2   district_name                     640 non-null    bool
#  3   Population                        640 non-null    bool
#  4   Male                              640 non-null    bool
#  5   Female                            640 non-null    bool
#  6   Literate                          640 non-null    bool
#  7   Male_Literate                     640 non-null    bool
#  8   Female_Literate                   640 non-null    bool
#  9   SC                                640 non-null    bool
#  10  Male_SC                           640 non-null    bool
#  11  Female_SC                         640 non-null    bool
# ...
